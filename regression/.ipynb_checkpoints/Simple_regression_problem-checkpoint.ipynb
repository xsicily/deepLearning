# %% [markdown]
# ## Outline
# #### In this assignment, you will learn:
# * How to generate random data using Pytorch.
# * How to build your own Pytorch model for simple regression problem on the generated data.
# * Training the model with gradient descent algorithm in Pytorch.
#
# #### Environment
# Python 3 + Pytorch (>=1.3).<br>
# Other libraries should be installed correctly such as numpy, matplotlib, *etc*., according to the dependencies of the assignment. <br>
#
# #### Database
# * Randomly synthesized data.

# %% [markdown]
# ## Part 1. Generate training and testing data using Pytorch
# Suppose we observe a real-valued input variable $x$ and we wish to use this observation to predict the value of a real-valued target variable $y$. For the present purposes, it is instructive to consider an artificial example using synthetically generated data because we then know the precise process that generated the data for comparison against any learned model.
#
# We therefore generate our training data which consists of 1000 pairs of $\{x_i, y_i\}$ where $\{x_i\}$ are generated uniformly, and the corresponding target values $\{y_i\}$ are obtained by first computing the corresponding values of a pre-defined function and then adding random noise with a Gaussian distribution having standard deviation 0.5.
# \begin{align*}
# y_i = 2.4 * x_i^{2} - 1.9 * x_i + 0.6 + \varepsilon, \varepsilon\sim \mathcal{N}(0,\,0.5^{2})
# \end{align*}
#
# The testing data is created the same way as training data **but without noise**, where the number of pairs is 100, in order to give a quantitative evaluation of the model to be trained.
#
# Please create the required training and testing data below and plot them. You could use [`torch.randn()`](https://pytorch.org/docs/stable/generated/torch.rand.html#torch.rand) to create the data and matplotlib.pyplot to show them.

# %% [markdown]
# Here, I would like to warm you up with a simple example using the function: $y = x^2 + \varepsilon, \varepsilon\sim \mathcal{N}(0,\,0.2^{2})$

# %%
import torch
import matplotlib.pyplot as plt

x = torch.randn(100)
y = torch.pow(x, 2) + torch.randn(100) * 0.2

plt.figure(figsize=(10, 5))
plt.rcParams.update({'font.size': 10})
plt.plot(x, y, marker='o', linestyle='none', markersize=5)
plt.show()

# %%
# TODO: (3 points, details are given below): 
# generate 1000 training data pairs and 100 testing data pairs according to the above description.

# generate training data (1 point)
x_train = torch.randn(1000)
y_train = 2.4 * torch.pow(x_train, 2) - 1.9 * x_train + 0.6 +  torch.randn(1000) * 0.5

# generate testing data (1 point)
x_test = torch.randn(100)
y_test = 2.4 * torch.pow(x_test, 2) - 1.9 * x_test + 0.6

# draw the data in a single figure (using two different showing styles) (1 point)
plt.figure(figsize=(40,20))
plt.rcParams.update({'font.size': 30})
plt.plot(x_train, y_train, marker='o', linestyle='none') 
plt.plot(x_test, y_test, marker='o', color='r', linestyle='none', markersize=15) 

plt.show()
plt.rcParams.update(plt.rcParamsDefault)

# %% [markdown]
# ## Part 2. Solving the regression problem in Pytorch using Gradient Descent Algorithm
#
# ### 2.1 Data
# Congratulations if you generate the data correctly! However, to make sure all of you use the same data, we have generated it in advance.

# %%
data = torch.load('dataset.pt')
x_train = data['x_train'] # 1000
y_train = data['y_train'] # 1000
x_test = data['x_test'] # 100
y_test = data['y_test'] # 100

# %% [markdown]
# ### 2.2 Model
# In this part, you will define your own model class. To do that, you have to remember the following rules:
# 1. The model class should be inherited from [`nn.Module`](https://pytorch.org/docs/stable/generated/torch.nn.Module.html#torch.nn.Module);
# 2. Re-write the **\_\_init\_\_** function and the **forward** function;
# 3. In the **\_\_init\_\_** function, you should always call the parent's **\_\_init\_\_** function first.
#
# To make it simpler, suppose we have already known the main structure of the function that generated the data:
# \begin{align*}
# y = a * x^2 + b*x + c.
# \end{align*}
#
# Therefore, in the model, we need to set 3 parameters: $a$, $b$ and $c$.

# %%
# TODO (3.5 points, details are given below)
import torch.nn as nn


# define a class (0.5) + write the __init__ function (1.5 point) + write the forward function (1.5 points)

class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        
        # define the parameters of the model: a, b, c
        self.a = nn.Parameter(torch.rand(1))
        self.b = nn.Parameter(torch.rand(1))
        self.c = nn.Parameter(torch.rand(1))

    def forward(self, data):
        # calculate the output
        x = data
        f = self.a * torch.pow(x, 2) + self.b * x + self.c
        return f

# %% [markdown]
# ### 2.3 Training
# Here, you will train your model based on the training data and evaluate the model on testing data.
# 1. Set proper number of iterations and learning rate.
# 2. Remember to use a proper optimizer (you may have many choices: Adam, SGD, RMSprop, ... please find the detailed information in https://pytorch.org/docs/stable/optim.html and know how to use them).
# 3. In order to train the model, a loss function should be defined:
# \begin{align*}
# loss = \frac{1}{N}\sum_{i=1}^{N}|f_i - y_i|,
# \end{align*}
# where, $f_i$ is the output of the model and $N$ is the number of training data pairs.
# 4. The model must be trained only using training data.
# 5. Remember to clear the old gradients of parameters before a new backward propagation.
# 6. In every certain number of iterations, print the values of the parameters, the training loss, and the testing loss.
# 7. Meanwhile, please track the training loss and the testing loss in each iteration. Once the training is done, the curves of losses should be plotted (two curves are drawn in the same figure, where x axis indicates iterations and y axis indicates the losses).
# 8. Lastly, draw all the training data, testing data and the curve of the trained model in the same figure (use different showing styles to distinguish them).

# %%
# TODO: (8.5 points, details are given below)
import numpy as np
# Make a instance of the model class (0.5 point)
model = Model()

# create an optimizer, set a workable learing rate (0.5 point + 0.5 point)

training_losses = []
testing_losses = []
n_itr = 10000

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
testing_loss_min = np.inf

for i in range(n_itr):
 
    # Train
    model.train() # change model to train mode
    # forward propagation

    # calculate the output of model (0.5 point)
    f = model(x_train)
    
    # calculate loss according to the above equation (0.5 point)
    training_loss = torch.abs(f - y_train).mean()
    # convert training_loss tensor to array
    training_losses.append(training_loss.item())
    
    # backward propagation 
    # clear old gradients (0.5)
    optimizer.zero_grad()
    # calculate gradients of parameters (1 point)
    training_loss.backward()
    # gradient descent algorithm (1 point)
    optimizer.step()
    
    # Evaluate, calculate the testing loss (0.5 point)
    model.eval() # change model to eval mode
    predicted_outputs = model(x_test)
    testing_loss = torch.abs(predicted_outputs - y_test).mean()
    # convert testing_loss tensor to array
    testing_losses.append(testing_loss.item())
    
    if testing_loss <= testing_loss_min:
        torch.save(model.state_dict(), './best_model.pt')
        testing_loss_min = testing_loss
        
    
    # print the values of the parameters, the training loss, and the testing loss in every 100 iterations
    if i % 100 == 0:
        print('Iteration:%f | a: %f | b: %f | c: %f | traning_losses: %f | testing_losses: %f' % (i, model.a.data, model.b.data, model.c.data, training_loss.data, testing_loss.data))
# Out:
# Iteration:0.000000 | a: 0.405976 | b: 0.893659 | c: 0.976841 | traning_losses: 16.412996 | testing_losses: 16.684387
# Iteration:100.000000 | a: 0.505938 | b: 0.791945 | c: 1.076041 | traning_losses: 15.499953 | testing_losses: 15.756117
# Iteration:200.000000 | a: 0.605878 | b: 0.690698 | c: 1.174330 | traning_losses: 14.590414 | testing_losses: 14.831577
# Iteration:300.000000 | a: 0.705718 | b: 0.583298 | c: 1.271201 | traning_losses: 13.684867 | testing_losses: 13.910182
# Iteration:400.000000 | a: 0.805513 | b: 0.472241 | c: 1.367003 | traning_losses: 12.782150 | testing_losses: 12.992363
# Iteration:500.000000 | a: 0.905204 | b: 0.356306 | c: 1.461481 | traning_losses: 11.883128 | testing_losses: 12.078697
# Iteration:600.000000 | a: 1.004796 | b: 0.241266 | c: 1.554203 | traning_losses: 10.989607 | testing_losses: 11.169513
# Iteration:700.000000 | a: 1.104343 | b: 0.124681 | c: 1.646393 | traning_losses: 10.098435 | testing_losses: 10.265049
# Iteration:800.000000 | a: 1.203738 | b: 0.010461 | c: 1.736667 | traning_losses: 9.214355 | testing_losses: 9.368082
# Iteration:900.000000 | a: 1.302938 | b: -0.100694 | c: 1.824243 | traning_losses: 8.339373 | testing_losses: 8.478647
# Iteration:1000.000000 | a: 1.401998 | b: -0.207465 | c: 1.909904 | traning_losses: 7.472126 | testing_losses: 7.599188
# Iteration:1100.000000 | a: 1.500452 | b: -0.310734 | c: 1.990786 | traning_losses: 6.623839 | testing_losses: 6.734120
# Iteration:1200.000000 | a: 1.598369 | b: -0.409151 | c: 2.067555 | traning_losses: 5.792607 | testing_losses: 5.886050
# Iteration:1300.000000 | a: 1.695864 | b: -0.496689 | c: 2.140744 | traning_losses: 4.977762 | testing_losses: 5.056035
# Iteration:1400.000000 | a: 1.792524 | b: -0.569623 | c: 2.207578 | traning_losses: 4.188495 | testing_losses: 4.252135
# Iteration:1500.000000 | a: 1.887914 | b: -0.633271 | c: 2.267640 | traning_losses: 3.430967 | testing_losses: 3.481779
# Iteration:1600.000000 | a: 1.980660 | b: -0.664403 | c: 2.315719 | traning_losses: 2.730996 | testing_losses: 2.765861
# Iteration:1700.000000 | a: 2.068880 | b: -0.671633 | c: 2.345747 | traning_losses: 2.113396 | testing_losses: 2.128186
# Iteration:1800.000000 | a: 2.149555 | b: -0.702750 | c: 2.350078 | traning_losses: 1.610198 | testing_losses: 1.600604
# Iteration:1900.000000 | a: 2.219977 | b: -0.701937 | c: 2.326607 | traning_losses: 1.234272 | testing_losses: 1.215480
# Iteration:2000.000000 | a: 2.265866 | b: -0.689532 | c: 2.257821 | traning_losses: 1.058188 | testing_losses: 1.021435
# Iteration:2100.000000 | a: 2.287361 | b: -0.696315 | c: 2.154001 | traning_losses: 0.978791 | testing_losses: 0.927504
# Iteration:2200.000000 | a: 2.298591 | b: -0.697712 | c: 2.041339 | traning_losses: 0.914409 | testing_losses: 0.855321
# Iteration:2300.000000 | a: 2.307342 | b: -0.694444 | c: 1.928826 | traning_losses: 0.852854 | testing_losses: 0.787617
# Iteration:2400.000000 | a: 2.314657 | b: -0.694419 | c: 1.818118 | traning_losses: 0.793994 | testing_losses: 0.722571
# Iteration:2500.000000 | a: 2.322045 | b: -0.693695 | c: 1.710906 | traning_losses: 0.738244 | testing_losses: 0.659229
# Iteration:2600.000000 | a: 2.328955 | b: -0.692764 | c: 1.608629 | traning_losses: 0.687546 | testing_losses: 0.599006
# Iteration:2700.000000 | a: 2.335520 | b: -0.692590 | c: 1.510366 | traning_losses: 0.640933 | testing_losses: 0.541189
# Iteration:2800.000000 | a: 2.341822 | b: -0.697455 | c: 1.416159 | traning_losses: 0.598407 | testing_losses: 0.485543
# Iteration:2900.000000 | a: 2.347999 | b: -0.696359 | c: 1.327428 | traning_losses: 0.560995 | testing_losses: 0.432995
# Iteration:3000.000000 | a: 2.353609 | b: -0.695054 | c: 1.244827 | traning_losses: 0.529203 | testing_losses: 0.384383
# Iteration:3100.000000 | a: 2.359935 | b: -0.697564 | c: 1.168584 | traning_losses: 0.502118 | testing_losses: 0.337567
# Iteration:3200.000000 | a: 2.364962 | b: -0.695883 | c: 1.095191 | traning_losses: 0.478113 | testing_losses: 0.294337
# Iteration:3300.000000 | a: 2.369498 | b: -0.693993 | c: 1.026405 | traning_losses: 0.457684 | testing_losses: 0.254284
# Iteration:3400.000000 | a: 2.373967 | b: -0.696268 | c: 0.963256 | traning_losses: 0.440902 | testing_losses: 0.216495
# Iteration:3500.000000 | a: 2.377731 | b: -0.696139 | c: 0.906504 | traning_losses: 0.427878 | testing_losses: 0.183262
# Iteration:3600.000000 | a: 2.381032 | b: -0.695514 | c: 0.858062 | traning_losses: 0.418760 | testing_losses: 0.154870
# Iteration:3700.000000 | a: 2.383819 | b: -0.694654 | c: 0.815934 | traning_losses: 0.412139 | testing_losses: 0.130514
# Iteration:3800.000000 | a: 2.386396 | b: -0.695663 | c: 0.777582 | traning_losses: 0.406869 | testing_losses: 0.107949
# Iteration:3900.000000 | a: 2.389268 | b: -0.695376 | c: 0.742974 | traning_losses: 0.402695 | testing_losses: 0.086759
# Iteration:4000.000000 | a: 2.391101 | b: -0.693423 | c: 0.712430 | traning_losses: 0.399676 | testing_losses: 0.070448
# Iteration:4100.000000 | a: 2.392691 | b: -0.692111 | c: 0.686652 | traning_losses: 0.397622 | testing_losses: 0.057179
# Iteration:4200.000000 | a: 2.394284 | b: -0.691700 | c: 0.663549 | traning_losses: 0.396036 | testing_losses: 0.045012
# Iteration:4300.000000 | a: 2.395139 | b: -0.691878 | c: 0.645499 | traning_losses: 0.395138 | testing_losses: 0.036764
# Iteration:4400.000000 | a: 2.396155 | b: -0.691737 | c: 0.634247 | traning_losses: 0.394786 | testing_losses: 0.030839
# Iteration:4500.000000 | a: 2.396726 | b: -0.692475 | c: 0.625847 | traning_losses: 0.394605 | testing_losses: 0.026164
# Iteration:4600.000000 | a: 2.397115 | b: -0.692880 | c: 0.619037 | traning_losses: 0.394493 | testing_losses: 0.023119
# Iteration:4700.000000 | a: 2.397346 | b: -0.692957 | c: 0.615580 | traning_losses: 0.394466 | testing_losses: 0.021752
# Iteration:4800.000000 | a: 2.397466 | b: -0.692885 | c: 0.613398 | traning_losses: 0.394455 | testing_losses: 0.021226
# Iteration:4900.000000 | a: 2.397531 | b: -0.692933 | c: 0.611922 | traning_losses: 0.394450 | testing_losses: 0.020824
# Iteration:5000.000000 | a: 2.397583 | b: -0.692911 | c: 0.611025 | traning_losses: 0.394449 | testing_losses: 0.020622
# Iteration:5100.000000 | a: 2.397587 | b: -0.692940 | c: 0.610852 | traning_losses: 0.394448 | testing_losses: 0.020557
# Iteration:5200.000000 | a: 2.397598 | b: -0.692850 | c: 0.610863 | traning_losses: 0.394449 | testing_losses: 0.020648
# Iteration:5300.000000 | a: 2.397586 | b: -0.692938 | c: 0.610860 | traning_losses: 0.394449 | testing_losses: 0.020564
# Iteration:5400.000000 | a: 2.397584 | b: -0.692931 | c: 0.610861 | traning_losses: 0.394448 | testing_losses: 0.020584
# Iteration:5500.000000 | a: 2.397593 | b: -0.692807 | c: 0.610848 | traning_losses: 0.394449 | testing_losses: 0.020734
# Iteration:5600.000000 | a: 2.397577 | b: -0.692919 | c: 0.610845 | traning_losses: 0.394449 | testing_losses: 0.020632
# Iteration:5700.000000 | a: 2.397579 | b: -0.692943 | c: 0.610852 | traning_losses: 0.394449 | testing_losses: 0.020588
# Iteration:5800.000000 | a: 2.397583 | b: -0.692877 | c: 0.610861 | traning_losses: 0.394448 | testing_losses: 0.020669
# Iteration:5900.000000 | a: 2.397578 | b: -0.692865 | c: 0.610812 | traning_losses: 0.394449 | testing_losses: 0.020705
# Iteration:6000.000000 | a: 2.397578 | b: -0.692972 | c: 0.610851 | traning_losses: 0.394449 | testing_losses: 0.020545
# Iteration:6100.000000 | a: 2.397581 | b: -0.692848 | c: 0.610854 | traning_losses: 0.394448 | testing_losses: 0.020719
# Iteration:6200.000000 | a: 2.397583 | b: -0.692931 | c: 0.610863 | traning_losses: 0.394448 | testing_losses: 0.020590
# Iteration:6300.000000 | a: 2.397581 | b: -0.692890 | c: 0.610858 | traning_losses: 0.394448 | testing_losses: 0.020659
# Iteration:6400.000000 | a: 2.397576 | b: -0.692923 | c: 0.610853 | traning_losses: 0.394449 | testing_losses: 0.020627
# Iteration:6500.000000 | a: 2.397590 | b: -0.692919 | c: 0.610860 | traning_losses: 0.394449 | testing_losses: 0.020578
# Iteration:6600.000000 | a: 2.397591 | b: -0.693042 | c: 0.610805 | traning_losses: 0.394449 | testing_losses: 0.020388
# Iteration:6700.000000 | a: 2.397594 | b: -0.692910 | c: 0.610842 | traning_losses: 0.394448 | testing_losses: 0.020574
# Iteration:6800.000000 | a: 2.397582 | b: -0.692683 | c: 0.610850 | traning_losses: 0.394449 | testing_losses: 0.020969
# Iteration:6900.000000 | a: 2.397566 | b: -0.692841 | c: 0.610844 | traning_losses: 0.394449 | testing_losses: 0.020793
# Iteration:7000.000000 | a: 2.397591 | b: -0.692733 | c: 0.610824 | traning_losses: 0.394450 | testing_losses: 0.020856
# Iteration:7100.000000 | a: 2.397584 | b: -0.692854 | c: 0.610838 | traning_losses: 0.394448 | testing_losses: 0.020697
# Iteration:7200.000000 | a: 2.397569 | b: -0.692694 | c: 0.610806 | traning_losses: 0.394450 | testing_losses: 0.021000
# Iteration:7300.000000 | a: 2.397592 | b: -0.692960 | c: 0.610848 | traning_losses: 0.394449 | testing_losses: 0.020509
# Iteration:7400.000000 | a: 2.397597 | b: -0.692990 | c: 0.610852 | traning_losses: 0.394449 | testing_losses: 0.020444
# Iteration:7500.000000 | a: 2.397582 | b: -0.692916 | c: 0.610844 | traning_losses: 0.394448 | testing_losses: 0.020614
# Iteration:7600.000000 | a: 2.397572 | b: -0.692908 | c: 0.610850 | traning_losses: 0.394448 | testing_losses: 0.020667
# Iteration:7700.000000 | a: 2.397550 | b: -0.693135 | c: 0.610831 | traning_losses: 0.394450 | testing_losses: 0.020432
# Iteration:7800.000000 | a: 2.397560 | b: -0.693108 | c: 0.610832 | traning_losses: 0.394450 | testing_losses: 0.020428
# Iteration:7900.000000 | a: 2.397576 | b: -0.693002 | c: 0.610810 | traning_losses: 0.394449 | testing_losses: 0.020510
# Iteration:8000.000000 | a: 2.397573 | b: -0.692915 | c: 0.610818 | traning_losses: 0.394450 | testing_losses: 0.020653
# Iteration:8100.000000 | a: 2.397612 | b: -0.692952 | c: 0.610834 | traning_losses: 0.394449 | testing_losses: 0.020436
# Iteration:8200.000000 | a: 2.397584 | b: -0.692968 | c: 0.610860 | traning_losses: 0.394449 | testing_losses: 0.020528
# Iteration:8300.000000 | a: 2.397639 | b: -0.692846 | c: 0.610844 | traning_losses: 0.394450 | testing_losses: 0.020499
# Iteration:8400.000000 | a: 2.397563 | b: -0.692758 | c: 0.610851 | traning_losses: 0.394449 | testing_losses: 0.020928
# Iteration:8500.000000 | a: 2.397587 | b: -0.692943 | c: 0.610820 | traning_losses: 0.394449 | testing_losses: 0.020551
# Iteration:8600.000000 | a: 2.397551 | b: -0.692792 | c: 0.610842 | traning_losses: 0.394449 | testing_losses: 0.020923
# Iteration:8700.000000 | a: 2.397558 | b: -0.692826 | c: 0.610845 | traning_losses: 0.394449 | testing_losses: 0.020847
# Iteration:8800.000000 | a: 2.397573 | b: -0.692803 | c: 0.610846 | traning_losses: 0.394450 | testing_losses: 0.020821
# Iteration:8900.000000 | a: 2.397587 | b: -0.693028 | c: 0.610816 | traning_losses: 0.394449 | testing_losses: 0.020425
# Iteration:9000.000000 | a: 2.397568 | b: -0.692956 | c: 0.610795 | traning_losses: 0.394449 | testing_losses: 0.020611
# Iteration:9100.000000 | a: 2.397607 | b: -0.693026 | c: 0.610861 | traning_losses: 0.394449 | testing_losses: 0.020347
# Iteration:9200.000000 | a: 2.397597 | b: -0.693054 | c: 0.610871 | traning_losses: 0.394449 | testing_losses: 0.020347
# Iteration:9300.000000 | a: 2.397601 | b: -0.692976 | c: 0.610888 | traning_losses: 0.394449 | testing_losses: 0.020448
# Iteration:9400.000000 | a: 2.397581 | b: -0.692629 | c: 0.610757 | traning_losses: 0.394450 | testing_losses: 0.021053
# Iteration:9500.000000 | a: 2.397608 | b: -0.693096 | c: 0.610857 | traning_losses: 0.394449 | testing_losses: 0.020239
# Iteration:9600.000000 | a: 2.397555 | b: -0.692930 | c: 0.610766 | traning_losses: 0.394449 | testing_losses: 0.020702
# Iteration:9700.000000 | a: 2.397593 | b: -0.692884 | c: 0.610770 | traning_losses: 0.394449 | testing_losses: 0.020615
# Iteration:9800.000000 | a: 2.397551 | b: -0.692991 | c: 0.610811 | traning_losses: 0.394451 | testing_losses: 0.020633
# Iteration:9900.000000 | a: 2.397552 | b: -0.692675 | c: 0.610789 | traning_losses: 0.394450 | testing_losses: 0.021096

# %%
# plot the traing losses (0.5 point) and testing losses (0.5 point)
# define the scope of x
iteration = range(0,10000)

# plot training losses
plt.plot(iteration, training_losses, 'g', label='train')
# plot testing losses
plt.plot(iteration, testing_losses, 'b', label='test')

plt.title('Training and Testing loss')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# plot all the training data, testing data and the curve of function (1 point)
model = torch.load('best_model.pt')
a = model['a'].item()
b = model['b'].item()
c = model['c'].item()

plt.figure(figsize=(40,20))
# plot training data
plt.plot(x_train, y_train, marker='o', linestyle='none') 
# plot testing data
plt.plot(x_test, y_test, marker='o', color='orange', linestyle='none', markersize=15) 
# plot the curve of function (best model)
plt.plot(x_train, a * torch.pow(x_train, 2) + b * x_train + c, color='r', linestyle='solid', markersize=2)

plt.show()
